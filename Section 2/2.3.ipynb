# %%
import pandas as pd
from sklearn.decomposition import FactorAnalysis
import time
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Factor analysis is another technique we can use to reduce dimensionality. However, factor analysis makes assumptions and PCA does not. The basic assumption is that there are implicit features responsible for the features of the dataset.

# %%
data = pd.read_csv('dimensionality_reduction_data.csv')

# %%
time_start = time.time()
fa = FactorAnalysis(n_components=2)
fa_results = fa.fit_transform(data)
print('FA done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# FA done! Time elapsed: 74.12344217300415 seconds

# %% [markdown]
# t-SNE = 1505 seconds
# PCA = 0.1 seconds
# FA = 77 seconds

# %%
data['fa-one'] = fa_results[:,0]
data['fa-two'] = fa_results[:,1]

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="fa-one", y="fa-two",
    palette=sns.color_palette("hls", 10),
    data=data,
    legend="full",
    alpha=0.3
)

# %% [markdown]
# The difference betweeen PCA and FA is that PCA transforms the N-dimensional dataset to M dimensions, where M < N.
#
# FA however assumes that there are only M important features and a linear combination of these features (plus noise) creates the N-dimensional space
